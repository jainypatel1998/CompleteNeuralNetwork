# %% [markdown]
# <a href="https://colab.research.google.com/github/jainypatel1998/CompleteNeuralNetwork/blob/master/NeuralNetworkDefined.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basic Instructions
#
# 1. Enter your Name and UID in the provided space.
# 2. Do the assignment in the notebook itself
# 3. you are free to use Google Colab

# %% [markdown]
# Name:  **Jainy Patel**
# UID:  **114631060**

# %% [markdown]
# In the first part, you will implement all the functions required to build a two layer neural network.
# In the next part, you will use these functions for image and text classification. Provide your code at the appropriate placeholders.

# %% [markdown]
# ## 1. Packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import scipy
import math
from PIL import Image
from scipy import ndimage

# %% [markdown]
# ## 2. Layer Initialization

# %% [markdown]
# **Exercise:** Create and initialize the parameters of the 2-layer neural network. Use random initialization for the weight matrices and zero initialization for the biases.

# %%
def initialize_parameters(n_x, n_h, n_y):
    """
    Argument:
    n_x -- size of the input layer
    n_h -- size of the hidden layer
    n_y -- size of the output layer
    
    Returns:
    parameters -- python dictionary containing your parameters:
                    W1 -- weight matrix of shape (n_h, n_x)
                    b1 -- bias vector of shape (n_h, 1)
                    W2 -- weight matrix of shape (n_y, n_h)
                    b2 -- bias vector of shape (n_y, 1)
    """
    
    np.random.seed(1)
    
    ### START CODE HERE ### (≈ 4 lines of code)
    W1 = 0.01 * np.random.randn(n_h, n_x)
    b1 = np.zeros((n_h, 1))
    W2 = 0.01 * np.random.randn(n_y, n_h)
    b2 = np.zeros((n_y, 1))
    ### END CODE HERE ###
    
    assert(W1.shape == (n_h, n_x))
    assert(b1.shape == (n_h, 1))
    assert(W2.shape == (n_y, n_h))
    assert(b2.shape == (n_y, 1))
    
    parameters = {"W1": W1,
                  "b1": b1,
                  "W2": W2,
                  "b2": b2}
    
    return parameters

# %%
parameters = initialize_parameters(3,2,1)
print("W1 = " + str(parameters["W1"]))
print("b1 = " + str(parameters["b1"]))
print("W2 = " + str(parameters["W2"]))
print("b2 = " + str(parameters["b2"]))
# Out:
# W1 = [[ 0.01624345 -0.00611756 -0.00528172]
#  [-0.01072969  0.00865408 -0.02301539]]
# b1 = [[0.]
#  [0.]]
# W2 = [[ 0.01744812 -0.00761207]]
# b2 = [[0.]]

# %% [markdown]
# **Expected output**:
#
# <table style="width:80%">
#   <tr>
#     <td> **W1** </td>
#     <td> [[ 0.01624345 -0.00611756 -0.00528172]
#  [-0.01072969  0.00865408 -0.02301539]] </td>
#   </tr>
#
#   <tr>
#     <td> **b1**</td>
#     <td>[[ 0.]
#  [ 0.]]</td>
#   </tr>
#
#   <tr>
#     <td>**W2**</td>
#     <td> [[ 0.01744812 -0.00761207]]</td>
#   </tr>
#
#   <tr>
#     <td> **b2** </td>
#     <td> [[ 0.]] </td>
#   </tr>
#
# </table>

# %% [markdown]
# ## 3. Forward Propagation

# %% [markdown]
# Now that you have initialized your parameters, you will do the forward propagation module. You will start by implementing some basic functions that you will use later when implementing the model. You will complete three functions in this order:
#
# - LINEAR
# - LINEAR -> ACTIVATION where ACTIVATION will be either ReLU or Sigmoid.
#
# The linear module computes the following equation:
#
# $$Z = WA+b\tag{4}$$
#
# ### 3.1 Exercise: Build the linear part of forward propagation.

# %%
def linear_forward(A, W, b):
    """
    Implement the linear part of a layer's forward propagation.

    Arguments:
    A -- activations from previous layer (or input data): (size of previous layer, number of examples)
    W -- weights matrix: numpy array of shape (size of current layer, size of previous layer)
    b -- bias vector, numpy array of shape (size of the current layer, 1)

    Returns:
    Z -- the input of the activation function, also called pre-activation parameter 
    cache -- a python dictionary containing "A", "W" and "b" ; stored for computing the backward pass efficiently
    """
    
    ### START CODE HERE ### (≈ 1 line of code)
    Z = np.dot(W,A) + b
    ### END CODE HERE ###
    
    assert(Z.shape == (W.shape[0], A.shape[1]))
    cache = (A, W, b)

    return Z, cache

# %%
np.random.seed(1)

A = np.random.randn(3,2)
W = np.random.randn(1,3)
b = np.random.randn(1,1)

Z, linear_cache = linear_forward(A, W, b)
print("Z = " + str(Z))
# Out:
# Z = [[ 3.26295337 -1.23429987]]

# %% [markdown]
# **Expected output**:
#
# <table style="width:35%">
#
#   <tr>
#     <td> **Z** </td>
#     <td> [[ 3.26295337 -1.23429987]] </td>
#   </tr>
#
# </table>

# %% [markdown]
# ### 3.2 - Linear-Activation Forward
#
# In this notebook, you will use two activation functions:
#
# - **Sigmoid**: $\sigma(Z) = \sigma(W A + b) = \frac{1}{ 1 + e^{-(W A + b)}}$. Write the code for the `sigmoid` function. This function returns **two** items: the activation value "`a`" and a "`cache`" that contains "`Z`" (it's what we will feed in to the corresponding backward function). To use it you could just call:
# ``` python
# A, activation_cache = sigmoid(Z)
# ```
#
# - **ReLU**: The mathematical formula for ReLu is $A = RELU(Z) = max(0, Z)$. Write the code for the  `relu` function. This function returns **two** items: the activation value "`A`" and a "`cache`" that contains "`Z`" (it's what we will feed in to the corresponding backward function). To use it you could just call:
# ``` python
# A, activation_cache = relu(Z)
#
# **Exercise**:
# - Implement the activation functions
# - Build the linear activation part of forward propagation. Mathematical relation is: $A = g(Z) = g(WA_{prev} +b)$

# %%
def sigmoid(Z):
    """
    Implements the sigmoid activation in numpy
    
    Arguments:
    Z -- numpy array of any shape
    
    Returns:
    A -- output of sigmoid(z), same shape as Z
    cache -- returns Z, useful during backpropagation
    """
    ### START CODE HERE ### (≈ 2 line of code)
    A = 1/(1 + np.exp(np.negative(Z)))
    cache = Z
    ### END CODE HERE ###
    
    return A, cache

def relu(Z):
    """
    Implement the RELU function.

    Arguments:
    Z -- Output of the linear layer, of any shape

    Returns:
    A -- Post-activation parameter, of the same shape as Z
    cache --  returns Z, useful during backpropagation
    """
    
    ### START CODE HERE ### (≈ 2 line of code)
    A = np.maximum(0, Z)
    cache = Z
    ### END CODE HERE ###
    
    assert(A.shape == Z.shape) 
    return A, cache

# %%
def linear_activation_forward(A_prev, W, b, activation):
    """
    Implement the forward propagation for the LINEAR->ACTIVATION layer

    Arguments:
    A_prev -- activations from previous layer (or input data): (size of previous layer, number of examples)
    W -- weights matrix: numpy array of shape (size of current layer, size of previous layer)
    b -- bias vector, numpy array of shape (size of the current layer, 1)
    activation -- the activation to be used in this layer, stored as a text string: "sigmoid" or "relu"

    Returns:
    A -- the output of the activation function, also called the post-activation value 
    cache -- a python dictionary containing "linear_cache" and "activation_cache";
             stored for computing the backward pass efficiently
    """
    
    if activation == "sigmoid":
        # Inputs: "A_prev, W, b". Outputs: "A, activation_cache".
        ### START CODE HERE ### (≈ 2 lines of code)
        jp, linear_cache = linear_forward(A_prev, W, b)
        A, activation_cache = sigmoid(jp)
        ### END CODE HERE ###
    
    elif activation == "relu":
        # Inputs: "A_prev, W, b". Outputs: "A, activation_cache".
        ### START CODE HERE ### (≈ 2 lines of code)
        jp, linear_cache = linear_forward(A_prev, W, b)
        A, activation_cache = relu(jp)
        ### END CODE HERE ###
    
    assert (A.shape == (W.shape[0], A_prev.shape[1]))
    cache = (linear_cache, activation_cache)

    return A, cache

# %%
np.random.seed(2)
A_prev = np.random.randn(3,2)
W = np.random.randn(1,3)
b = np.random.randn(1,1)

A, linear_activation_cache = linear_activation_forward(A_prev, W, b, activation = "sigmoid")
print("With sigmoid: A = " + str(A))

A, linear_activation_cache = linear_activation_forward(A_prev, W, b, activation = "relu")
print("With ReLU: A = " + str(A))
# Out:
# With sigmoid: A = [[0.96890023 0.11013289]]
# With ReLU: A = [[3.43896131 0.        ]]

# %% [markdown]
# **Expected output**:
#
# <table style="width:35%">
#   <tr>
#     <td> **With sigmoid: A ** </td>
#     <td > [[ 0.96890023  0.11013289]]</td>
#   </tr>
#   <tr>
#     <td> **With ReLU: A ** </td>
#     <td > [[ 3.43896131  0.        ]]</td>
#   </tr>
# </table>

# %% [markdown]
# ## 4 - Loss function
#
# Now you will implement forward and backward propagation. You need to compute the loss, because you want to check if your model is actually learning.
#
# **Exercise**: Compute the cross-entropy loss $J$, using the following formula: $$-\frac{1}{m} \sum\limits_{i = 1}^{m} (y^{(i)}\log\left(a^{ (i)}\right) + (1-y^{(i)})\log\left(1- a^{(i)}\right)) \tag{7}$$

# %%
# GRADED FUNCTION: compute_loss

def compute_loss(A, Y):
    """
    Implement the loss function defined by equation (7).

    Arguments:
    A -- probability vector corresponding to your label predictions, shape (1, number of examples)
    Y -- true "label" vector (for example: containing 0 if non-cat, 1 if cat), shape (1, number of examples)

    Returns:
    loss -- cross-entropy loss
    """
    
    m = Y.shape[1]

    # Compute loss from aL and y.
    ### START CODE HERE ### (≈ 1 lines of code)
    loss = []
    for i in range (0,m):
      loss.append((Y[0][i] * np.log(A[0][i])) + ((1-Y[0][i]) * np.log(1-A[0][i])))
    loss = np.sum(loss) * (np.negative(1./m))
    ### END CODE HERE ###
  
    loss = np.squeeze(loss)      # To make sure your loss's shape is what we expect (e.g. this turns [[17]] into 17).
    assert(loss.shape == ())
    
    return loss

# %%
Y = np.asarray([[1, 1, 1]])
A = np.array([[.8,.9,0.4]])

print("loss = " + str(compute_loss(A, Y)))
# Out:
# loss = 0.41493159961539694

# %% [markdown]
# **Expected Output**:
#
# <table>
#     <tr>
#     <td>**loss** </td>
#     <td> 0.41493159961539694</td>
#     </tr>
# </table>

# %% [markdown]
# ## 5 - Backward propagation module
#
# Just like with forward propagation, you will implement helper functions for backpropagation. Remember that back propagation is used to calculate the gradient of the loss function with respect to the parameters.
#
# Now, similar to forward propagation, you are going to build the backward propagation in two steps:
# - LINEAR backward
# - LINEAR -> ACTIVATION backward where ACTIVATION computes the derivative of either the ReLU or sigmoid activation
#
# ### 5.1 - Linear backward

# %%
# GRADED FUNCTION: linear_backward

def linear_backward(dZ, cache):
    """
    Implement the linear portion of backward propagation for a single layer (layer l)

    Arguments:
    dZ -- Gradient of the loss with respect to the linear output (of current layer l)
    cache -- tuple of values (A_prev, W, b) coming from the forward propagation in the current layer

    Returns:
    dA_prev -- Gradient of the loss with respect to the activation (of the previous layer l-1), same shape as A_prev
    dW -- Gradient of the loss with respect to W (current layer l), same shape as W
    db -- Gradient of the loss with respect to b (current layer l), same shape as b
    """
    #import pdb;pdb.set_trace()
    A_prev, W, b = cache
    m = A_prev.shape[1]

    ### START CODE HERE ### (≈ 3 lines of code)
    dA_prev = np.dot(W.T, dZ)
    dW = 2 * (1./m) * np.dot(dZ,A_prev.T)
    db = 2 * (1./m) * np.sum(dZ, axis = 1, keepdims = True)
    ### END CODE HERE ###
    
    assert (dA_prev.shape == A_prev.shape)
    assert (dW.shape == W.shape)
    assert (db.shape == b.shape)
    
    return dA_prev, dW, db

# %%
np.random.seed(1)
dZ = np.random.randn(1,2)
A = np.random.randn(3,2)
W = np.random.randn(1,3)
b = np.random.randn(1,1)
linear_cache = (A, W, b)

dA_prev, dW, db = linear_backward(dZ, linear_cache)
print ("dA_prev = "+ str(dA_prev))
print ("dW = " + str(dW))
print ("db = " + str(db))
# Out:
# dA_prev = [[ 0.51822968 -0.19517421]
#  [-0.40506361  0.15255393]
#  [ 2.37496825 -0.89445391]]
# dW = [[-0.2015379   2.81370193  3.2998501 ]]
# db = [[1.01258895]]

# %% [markdown]
# **Expected Output**:
#
# <table style="width:90%">
#   <tr>
#     <td> **dA_prev** </td>
#     <td > [[ 0.51822968 -0.19517421]
#  [-0.40506361  0.15255393]
#  [ 2.37496825 -0.89445391]] </td>
#   </tr>
#     <tr>
#         <td> **dW** </td>
#         <td > [[-0.2015379   2.81370193  3.2998501 ]] </td>
#     </tr>
#     <tr>
#         <td> **db** </td>
#         <td> [[1.01258895]] </td>
#     </tr>
# </table>

# %% [markdown]
# ### 5.2 - Linear Activation backward
#
# Next, you will create a function that merges the two helper functions: **`linear_backward`** and the backward step for the activation **`linear_activation_backward`**.
#
# Before implementing `linear_activation_backward`, you need to implement two backward functions for each activations:
# - **`sigmoid_backward`**: Implements the backward propagation for SIGMOID unit. You can call it as follows:
#
# ```python
# dZ = sigmoid_backward(dA, activation_cache)
# ```
#
# - **`relu_backward`**: Implements the backward propagation for RELU unit. You can call it as follows:
#
# ```python
# dZ = relu_backward(dA, activation_cache)
# ```
#
# If $g(.)$ is the activation function,
# `sigmoid_backward` and `relu_backward` compute $$dZ^{[l]} = dA^{[l]} * g'(Z^{[l]}) \tag{11}$$.
#
# **Exercise**:
# - Implement the backward functions for the relu and sigmoid activation layer.
# - Implement the backpropagation for the *LINEAR->ACTIVATION* layer.

# %%
def relu_backward(dA, cache):
    """
    Implement the backward propagation for a single RELU unit.

    Arguments:
    dA -- post-activation gradient, of any shape
    cache -- 'Z' where we store for computing backward propagation efficiently

    Returns:
    dZ -- Gradient of the loss with respect to Z
    """
    
    Z = cache
    dZ = np.array(dA, copy=True) # just converting dz to a correct object.
    
    ### START CODE HERE ### (≈ 1 line of code)
    size = len(Z[0])
    for i in range(0,size):
      if Z[0][i] <= 0:
        dZ [0][i] = 0
    ### END CODE HERE ###
    
    assert (dZ.shape == Z.shape)
    
    return dZ

def sigmoid_backward(dA, cache):
    """
    Implement the backward propagation for a single SIGMOID unit.

    Arguments:
    dA -- post-activation gradient, of any shape
    cache -- 'Z' where we store for computing backward propagation efficiently

    Returns:
    dZ -- Gradient of the loss with respect to Z
    """
    #import pdb;pdb.set_trace()
    Z = cache
    
    ### START CODE HERE ### (≈ 2 line of code)
    s = 1/(1+np.exp(-Z))
    dZ = dA * s * (1-s)
    ### END CODE HERE ###
    
    assert (dZ.shape == Z.shape)
    
    return dZ

# %%
# GRADED FUNCTION: linear_activation_backward

def linear_activation_backward(dA, cache, activation):
    """
    Implement the backward propagation for the LINEAR->ACTIVATION layer.
    
    Arguments:
    dA -- post-activation gradient for current layer l 
    cache -- tuple of values (linear_cache, activation_cache) we store for computing backward propagation efficiently
    activation -- the activation to be used in this layer, stored as a text string: "sigmoid" or "relu"
    
    Returns:
    dA_prev -- Gradient of the loss with respect to the activation (of the previous layer l-1), same shape as A_prev
    dW -- Gradient of the loss with respect to W (current layer l), same shape as W
    db -- Gradient of the loss with respect to b (current layer l), same shape as b
    """
    linear_cache, activation_cache = cache
    
    if activation == "relu":
        ### START CODE HERE ### (≈ 2 lines of code)
        #import pdb;pdb.set_trace()
        dZ = relu_backward(dA, activation_cache)
        dA_prev, dW, db = linear_backward(dZ, linear_cache)
        ### END CODE HERE ###
        
    elif activation == "sigmoid":
        ### START CODE HERE ### (≈ 2 lines of code)
        #import pdb;pdb.set_trace()
        dZ = sigmoid_backward(dA, activation_cache)
        dA_prev, dW, db = linear_backward(dZ, linear_cache)
        ### END CODE HERE ###

    return dA_prev, dW, db

# %%
np.random.seed(2)
dA = np.random.randn(1,2)
A = np.random.randn(3,2)
W = np.random.randn(1,3)
b = np.random.randn(1,1)
Z = np.random.randn(1,2)
linear_cache = (A, W, b)
activation_cache = Z
linear_activation_cache = (linear_cache, activation_cache)

dA_prev, dW, db = linear_activation_backward(dA, linear_activation_cache, activation = "sigmoid")
print ("sigmoid:")
print ("dA_prev = "+ str(dA_prev))
print ("dW = " + str(dW))
print ("db = " + str(db) + "\n")

dA_prev, dW, db = linear_activation_backward(dA, linear_activation_cache, activation = "relu")
print ("relu:")
print ("dA_prev = "+ str(dA_prev))
print ("dW = " + str(dW))
print ("db = " + str(db))
# Out:
# sigmoid:
# dA_prev = [[ 0.11017994  0.01105339]
#  [ 0.09466817  0.00949723]
#  [-0.05743092 -0.00576154]]
# dW = [[ 0.20533573  0.19557101 -0.03936168]]
# db = [[-0.11459244]]
#
# relu:
# dA_prev = [[ 0.44090989  0.        ]
#  [ 0.37883606  0.        ]
#  [-0.2298228   0.        ]]
# dW = [[ 0.89027649  0.74742835 -0.20957978]]
# db = [[-0.41675785]]

# %% [markdown]
# **Expected output with sigmoid:**
#
# <table style="width:100%">
#   <tr>
#     <td > dA_prev </td>
#            <td >[[ 0.11017994  0.01105339]
#  [ 0.09466817  0.00949723]
#  [-0.05743092 -0.00576154]] </td>
#   </tr>
#     <tr>
#     <td > dW </td>
#            <td > [[ 0.20533573  0.19557101 -0.03936168]] </td>
#   </tr>
#     <tr>
#     <td > db </td>
#            <td > [[-0.11459244]] </td>
#   </tr>
# </table>

# %% [markdown]
# **Expected output with relu:**
#
# <table style="width:100%">
#   <tr>
#     <td > dA_prev </td>
#            <td > [[ 0.44090989  0.        ]
#  [ 0.37883606  0.        ]
#  [-0.2298228   0.        ]] </td>
#   </tr>
#     <tr>
#     <td > dW </td>
#            <td > [[ 0.89027649  0.74742835 -0.20957978]] </td>
#   </tr>
#     <tr>
#     <td > db </td>
#            <td > [[-0.41675785]] </td>
#   </tr>
# </table>

# %% [markdown]
# ### 6 - Update Parameters
#
# In this section you will update the parameters of the model, using gradient descent:
#
# $$ W^{[1]} = W^{[1]} - \alpha \text{ } dW^{[1]} \tag{16}$$
# $$ b^{[1]} = b^{[1]} - \alpha \text{ } db^{[1]} \tag{17}$$
# $$ W^{[2]} = W^{[2]} - \alpha \text{ } dW^{[2} \tag{16}$$
# $$ b^{[2]} = b^{[2]} - \alpha \text{ } db^{[2]} \tag{17}$$
#
# where $\alpha$ is the learning rate. After computing the updated parameters, store them in the parameters dictionary.
#
# **Exercise**: Implement `update_parameters()` to update your parameters using gradient descent.
#
# **Instructions**:
# Update parameters using gradient descent.

# %%
# GRADED FUNCTION: update_parameters

def update_parameters(parameters, grads, learning_rate):
    """
    Update parameters using gradient descent
    
    Arguments:
    parameters -- python dictionary containing your parameters 
    grads -- python dictionary containing your gradients, output of L_model_backward
    
    Returns:
    parameters -- python dictionary containing your updated parameters 
                  parameters["W" + str(l)] = ... 
                  parameters["b" + str(l)] = ...
    """
    # Update rule for each parameter. Use a for loop.
    ### START CODE HERE ### (≈ 4 lines of code)
    if len(parameters) % 2 == 1:
      length = (len(parameters) + 1)/2
    else: 
      length = len(parameters)/2

    length = int(length) 

    for l in range (1, length+1):
      parameters["W" + str(l)] = parameters["W" + str(l)] - learning_rate * grads["dW" + str(l)]
      parameters["b" + str(l)] = parameters["b" + str(l)] - learning_rate * grads["db" + str(l)]                 
    ### END CODE HERE ###
    
    return parameters

# %%
np.random.seed(2)
W1 = np.random.randn(3,4)
b1 = np.random.randn(3,1)
W2 = np.random.randn(1,3)
b2 = np.random.randn(1,1)
parameters = {"W1": W1,
              "b1": b1,
              "W2": W2,
              "b2": b2}
np.random.seed(3)
dW1 = np.random.randn(3,4)
db1 = np.random.randn(3,1)
dW2 = np.random.randn(1,3)
db2 = np.random.randn(1,1)
grads = {"dW1": dW1,
         "db1": db1,
         "dW2": dW2,
         "db2": db2}
parameters = update_parameters(parameters, grads, 0.1)

print ("W1 = "+ str(parameters["W1"]))
print ("b1 = "+ str(parameters["b1"]))
print ("W2 = "+ str(parameters["W2"]))
print ("b2 = "+ str(parameters["b2"]))
# Out:
# W1 = [[-0.59562069 -0.09991781 -2.14584584  1.82662008]
#  [-1.76569676 -0.80627147  0.51115557 -1.18258802]
#  [-1.0535704  -0.86128581  0.68284052  2.20374577]]
# b1 = [[-0.04659241]
#  [-1.28888275]
#  [ 0.53405496]]
# W2 = [[-0.55569196  0.0354055   1.32964895]]
# b2 = [[-0.84610769]]

# %% [markdown]
# **Expected Output**:
#
# <table style="width:100%">
#     <tr>
#     <td > W1 </td>
#            <td > [[-0.59562069 -0.09991781 -2.14584584  1.82662008]
#  [-1.76569676 -0.80627147  0.51115557 -1.18258802]
#  [-1.0535704  -0.86128581  0.68284052  2.20374577]] </td>
#   </tr>
#     <tr>
#     <td > b1 </td>
#            <td > [[-0.04659241]
#  [-1.28888275]
#  [ 0.53405496]] </td>
#   </tr>
#   <tr>
#     <td > W2 </td>
#            <td > [[-0.55569196  0.0354055   1.32964895]]</td>
#   </tr>
#     <tr>
#     <td > b2 </td>
#            <td > [[-0.84610769]] </td>
#   </tr>
# </table>

# %% [markdown]
# ## 7 - Conclusion
#
# Congrats on implementing all the functions required for building a deep neural network!
#
# We know it was a long assignment but going forward it will only get better. The next part of the assignment is easier.

# %% [markdown]
# # Part 2:
#
# In the next part you will put all these together to build a two-layer neural networks for image classification.

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (5.0, 4.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %load_ext autoreload
# %autoreload 2

np.random.seed(1)

# %% [markdown]
# # Dataset

# %% [markdown]
# **Problem Statement**: You are given a dataset ("data/train_catvnoncat.h5", "data/test_catvnoncat.h5") containing:
#     - a training set of m_train images labelled as cat (1) or non-cat (0)
#     - a test set of m_test images labelled as cat and non-cat
#     - each image is of shape (num_px, num_px, 3) where 3 is for the 3 channels (RGB).
#
# Let's get more familiar with the dataset. Load the data by completing the function and run the cell below.

# %%
def load_data(train_file, test_file):
    # Load the training data
    train_dataset = h5py.File(train_file, 'r')

    # Separate features(x) and labels(y) for training set
    train_set_x_orig = np.array(train_dataset["train_set_x"][:])
    train_set_y_orig = np.array(train_dataset["train_set_y"][:])

    # Load the test data
    test_dataset = h5py.File(test_file, 'r')
    
    # Separate features(x) and labels(y) for training set
    test_set_x_orig = np.array(test_dataset["test_set_x"][:])
    test_set_y_orig = np.array(test_dataset["test_set_y"][:])

    classes = np.array(test_dataset["list_classes"][:]) # the list of classes
    
    train_set_y_orig = train_set_y_orig.reshape((1, train_set_y_orig.shape[0]))
    test_set_y_orig = test_set_y_orig.reshape((1, test_set_y_orig.shape[0]))
    
    return train_set_x_orig, train_set_y_orig, test_set_x_orig, test_set_y_orig, classes

# %%
train_file="data/train_catvnoncat.h5"
test_file="data/test_catvnoncat.h5"
train_x_orig, train_y, test_x_orig, test_y, classes = load_data(train_file, test_file)

# %% [markdown]
# The following code will show you an image in the dataset. Feel free to change the index and re-run the cell multiple times to see other images.

# %%
# Example of a picture
index = 10
plt.imshow(train_x_orig[index])
print ("y = " + str(train_y[0,index]) + ". It's a " + classes[train_y[0,index]].decode("utf-8") +  " picture.")
# Out:
# y = 0. It's a non-cat picture.

# %%
# Explore your dataset 
m_train = train_x_orig.shape[0]
num_px = train_x_orig.shape[1]
m_test = test_x_orig.shape[0]

print ("Number of training examples: " + str(m_train))
print ("Number of testing examples: " + str(m_test))
print ("Each image is of size: (" + str(num_px) + ", " + str(num_px) + ", 3)")
print ("train_x_orig shape: " + str(train_x_orig.shape))
print ("train_y shape: " + str(train_y.shape))
print ("test_x_orig shape: " + str(test_x_orig.shape))
print ("test_y shape: " + str(test_y.shape))
# Out:
# Number of training examples: 209
# Number of testing examples: 50
# Each image is of size: (64, 64, 3)
# train_x_orig shape: (209, 64, 64, 3)
# train_y shape: (1, 209)
# test_x_orig shape: (50, 64, 64, 3)
# test_y shape: (1, 50)

# %% [markdown]
# As usual, you reshape and standardize the images before feeding them to the network.
#
# <img src="imvectorkiank.png" style="width:450px;height:300px;">
#
# <caption><center> <u>Figure 1</u>: Image to vector conversion. <br> </center></caption>

# %%
# Reshape the training and test examples 
train_x_flatten = train_x_orig.reshape(train_x_orig.shape[0], -1).T   # The "-1" makes reshape flatten the remaining dimensions
test_x_flatten = test_x_orig.reshape(test_x_orig.shape[0], -1).T

# Standardize data to have feature values between 0 and 1.
train_x = train_x_flatten/255.
test_x = test_x_flatten/255.

print ("train_x's shape: " + str(train_x.shape))
print ("test_x's shape: " + str(test_x.shape))
# Out:
# train_x's shape: (12288, 209)
# test_x's shape: (12288, 50)

# %% [markdown]
# ## 3 - Architecture of your model
#
# Now that you are familiar with the dataset, it is time to build a deep neural network to distinguish cat images from non-cat images.
#
# ###  2-layer neural network
#
# <img src="2layerNN_kiank.png" style="width:650px;height:400px;">
# <caption><center> <u>Figure 2</u>: 2-layer neural network. <br> The model can be summarized as: ***INPUT -> LINEAR -> RELU -> LINEAR -> SIGMOID -> OUTPUT***. </center></caption>
#
# <u>Detailed Architecture of figure 2</u>:
# - The input is a (64,64,3) image which is flattened to a vector of size $(12288,1)$.
# - The corresponding vector: $[x_0,x_1,...,x_{12287}]^T$ is then multiplied by the weight matrix $W^{[1]}$ of size $(n^{[1]}, 12288)$.
# - You then add a bias term and take its relu to get the following vector: $[a_0^{[1]}, a_1^{[1]},..., a_{n^{[1]}-1}^{[1]}]^T$.
# - You multiply the resulting vector by $W^{[2]}$ and add your intercept (bias).
# - Finally, you take the sigmoid of the result. If it is greater than 0.5, you classify it to be a cat.
#
#
# ###  General methodology
#
# As usual you will follow the Deep Learning methodology to build the model:
#     1. Initialize parameters / Define hyperparameters
#     2. Loop for num_iterations:
#         a. Forward propagation
#         b. Compute loss function
#         c. Backward propagation
#         d. Update parameters (using parameters, and grads from backprop)
#     4. Use trained parameters to predict labels
#
# Let's now implement those the model!

# %% [markdown]
# **Question**:  Use the helper functions you have implemented in the previous assignment to build a 2-layer neural network with the following structure: *LINEAR -> RELU -> LINEAR -> SIGMOID*. The functions you may need and their inputs are:
# ```python
# def initialize_parameters(n_x, n_h, n_y):
#     ...
#     return parameters
# def linear_activation_forward(A_prev, W, b, activation):
#     ...
#     return A, cache
# def compute_loss(AL, Y):
#     ...
#     return loss
# def linear_activation_backward(dA, cache, activation):
#     ...
#     return dA_prev, dW, db
# def update_parameters(parameters, grads, learning_rate):
#     ...
#     return parameters
# ```

# %%
### CONSTANTS DEFINING THE MODEL ####
n_x = 12288     # num_px * num_px * 3
n_h = 7
n_y = 1
layers_dims = (n_x, n_h, n_y)

# %%
def two_layer_model(X, Y, layers_dims, learning_rate = 0.0075, num_iterations = 3000, print_loss=False):
    """
    Implements a two-layer neural network: LINEAR->RELU->LINEAR->SIGMOID.
    
    Arguments:
    X -- input data, of shape (n_x, number of examples)
    Y -- true "label" vector (containing 0 if cat, 1 if non-cat), of shape (1, number of examples)
    layers_dims -- dimensions of the layers (n_x, n_h, n_y)
    num_iterations -- number of iterations of the optimization loop
    learning_rate -- learning rate of the gradient descent update rule
    print_loss -- If set to True, this will print the loss every 100 iterations 
    
    Returns:
    parameters -- a dictionary containing W1, W2, b1, and b2
    """
    
    np.random.seed(1)
    grads = {}
    losses = []                              # to keep track of the loss
    m = X.shape[1]                           # number of examples
    (n_x, n_h, n_y) = layers_dims
    
    # Initialize parameters dictionary, by calling one of the functions you'd previously implemented
    ### START CODE HERE ### (≈ 1 line of code)
    parameters = initialize_parameters(n_x, n_h, n_y)
    ### END CODE HERE ###
    
    # Get W1, b1, W2 and b2 from the dictionary parameters.
    W1 = parameters["W1"]
    b1 = parameters["b1"]
    W2 = parameters["W2"]
    b2 = parameters["b2"]
    
    # Loop (gradient descent)

    for i in range(0, num_iterations):

        # Forward propagation: LINEAR -> RELU -> LINEAR -> SIGMOID. Inputs: "X, W1, b1, W2, b2". Output: "A1, cache1, A2, cache2".
        ### START CODE HERE ### (≈ 2 lines of code)
        A1, cache1 = linear_activation_forward(X, W1, b1, "relu")
        A2, cache2 = linear_activation_forward(A1, W2, b2, "sigmoid")
        ### END CODE HERE ###
        
        # Compute loss
        ### START CODE HERE ### (≈ 1 line of code)
        loss = compute_loss(A2, Y)
        ### END CODE HERE ###
        
        # Initializing backward propagation
        dA2 = - (np.divide(Y, A2) - np.divide(1 - Y, 1 - A2)) / m
        
        # Backward propagation. Inputs: "dA2, cache2, cache1". Outputs: "dA1, dW2, db2; also dA0 (not used), dW1, db1".
        ### START CODE HERE ### (≈ 2 lines of code)
        dA1, dW2, db2 = linear_activation_backward(dA2, cache2, "sigmoid")
        dA0, dW1, db1 = linear_activation_backward(dA1, cache1, "relu")
        ### END CODE HERE ###
        
        # Set grads['dWl'] to dW1, grads['db1'] to db1, grads['dW2'] to dW2, grads['db2'] to db2
        ### START CODE HERE ### (≈ 4 lines of code)
        grads['dW1'] = dW1
        grads['db1'] = db1
        grads['dW2'] = dW2
        grads['db2'] = db2
        ### END CODE HERE ###
        
    
        # Update parameters.
        ### START CODE HERE ### (approx. 1 line of code)
        update_parameters(parameters, grads, learning_rate)
        ### END CODE HERE ###

        # Retrieve W1, b1, W2, b2 from parameters
        W1 = parameters["W1"]
        b1 = parameters["b1"]
        W2 = parameters["W2"]
        b2 = parameters["b2"]
        
        # Print the loss every 100 training example
        if print_loss and i % 100 == 0:
            print("Loss after iteration {}: {}".format(i, np.squeeze(loss)))
        if print_loss and i % 100 == 0:
            losses.append(loss)
       
    # plot the loss

    plt.plot(np.squeeze(losses))
    plt.ylabel('loss')
    plt.xlabel('iterations (per tens)')
    plt.title("Learning rate =" + str(learning_rate))
    plt.show()
    
    return parameters

# %%
parameters = two_layer_model(train_x, train_y, layers_dims = (n_x, n_h, n_y), num_iterations = 2500, print_loss=True)
# Out:
# Loss after iteration 0: 0.693049735659989
# Loss after iteration 100: 0.6925509906961175
# Loss after iteration 200: 0.6920696880836005
# Loss after iteration 300: 0.6916223629342224
# Loss after iteration 400: 0.6911997217574759
# Loss after iteration 500: 0.6907978947616481
# Loss after iteration 600: 0.6904026976101533
# Loss after iteration 700: 0.6900023517428827
# Loss after iteration 800: 0.6896005719239727
# Loss after iteration 900: 0.6891905573130767
# Loss after iteration 1000: 0.6887697952539348
# Loss after iteration 1100: 0.6883375450548913
# Loss after iteration 1200: 0.687888343404039
# Loss after iteration 1300: 0.6874186788952527
# Loss after iteration 1400: 0.6869275298789033
# Loss after iteration 1500: 0.6864134957337904
# Loss after iteration 1600: 0.6858750001954605
# Loss after iteration 1700: 0.6853115591328176
# Loss after iteration 1800: 0.6847210761006156
# Loss after iteration 1900: 0.6841023898528007
# Loss after iteration 2000: 0.6834566894248109
# Loss after iteration 2100: 0.6827812580763748
# Loss after iteration 2200: 0.6820750067609292
# Loss after iteration 2300: 0.6813378436616245
# Loss after iteration 2400: 0.6805691662780118

# %% [markdown]
# **Expected Output**:
# <table>
#     <tr>
#         <td> **Loss after iteration 0**</td>
#         <td> 0.6930497356599888 </td>
#     </tr>
#     <tr>
#         <td> **Loss after iteration 100**</td>
#         <td> 0.6464320953428849 </td>
#     </tr>
#     <tr>
#         <td> **...**</td>
#         <td> ... </td>
#     </tr>
#     <tr>
#         <td> **Loss after iteration 2400**</td>
#         <td> 0.048554785628770206 </td>
#     </tr>
# </table>

# %% [markdown]
# Good thing you built a vectorized implementation! Otherwise it might have taken 10 times longer to train this.
#
# Now, you can use the trained parameters to classify images from the dataset.
#
# ***Exercise:***
# - Implement the forward function
# - Implement the predict function below to make prediction on test_images

# %%
def two_layer_forward(X, parameters):
    """
    Implement forward propagation for the [LINEAR->RELU]*(L-1)->LINEAR->SIGMOID computation
    
    Arguments:
    X -- data, numpy array of shape (input size, number of examples)
    parameters -- output of initialize_parameters_deep()
    
    Returns:
    AL -- last post-activation value
    caches -- list of caches containing:
                every cache of linear_relu_forward() (there are L-1 of them, indexed from 0 to L-2)
                the cache of linear_sigmoid_forward() (there is one, indexed L-1)
    """

    caches = []
    A = X
    
    # Implement LINEAR -> RELU. Add "cache" to the "caches" list.
    ### START CODE HERE ### (approx. 3 line of code)
    A1, cache = linear_activation_forward(A, parameters["W1"], parameters["b1"], "relu")
    caches.append(cache)
    ### END CODE HERE ###

    # Implement LINEAR -> SIGMOID. Add "cache" to the "caches" list.
    ### START CODE HERE ### (approx. 3 line of code)
    A2, cache = linear_activation_forward(A1, parameters["W2"], parameters["b2"], "sigmoid")
    caches.append(cache)
    ### END CODE HERE ###

    assert(A2.shape == (1,X.shape[1]))
            
    return A2, caches

# %%
def predict(X, y, parameters):
    """
    This function is used to predict the results of a  L-layer neural network.
    
    Arguments:
    X -- data set of examples you would like to label
    parameters -- parameters of the trained model
    
    Returns:
    p -- predictions for the given dataset X
    """
    
    m = X.shape[1]
    n = len(parameters) // 2 # number of layers in the neural network
    p = np.zeros((1,m))
    
    # Forward propagation
    ### START CODE HERE ### (≈ 1 lines of code)
    probas, caches =  two_layer_forward(X, parameters)
    ### END CODE HERE ###
    
    # convert probas to 0/1 predictions
    for i in range(0, probas.shape[1]):
        ### START CODE HERE ### (≈ 4 lines of code)
        if probas[0][i] >= 0.5:
          p[0][i] = 1
        ### END CODE HERE ###
    
    print("Accuracy: "  + str(np.sum((p == y)/m)))
        
    return p

# %%
predictions_train = predict(train_x, train_y, parameters)
# Out:
# Accuracy: 0.6555023923444976

# %%
predictions_test = predict(test_x, test_y, parameters)
# Out:
# Accuracy: 0.3400000000000001

# %% [markdown]
# ***Exercise:***
# Identify the hyperparameters in the model and For each hyperparameter
# - Briefly explain its role
# - Explore a range of values and describe their impact on (a) training loss and (b) test accuracy
# - Report the best hyperparameter value found.
#
# Note: Provide your results and explanations in the report for this question.

# %% [markdown]
# ##  Results Analysis
#
# First, let's take a look at some images the 2-layer model labeled incorrectly. This will show a few mislabeled images.

# %%
def print_mislabeled_images(classes, X, y, p):
    """
    Plots images where predictions and truth were different.
    X -- dataset
    y -- true labels
    p -- predictions
    """
    a = p + y
    mislabeled_indices = np.asarray(np.where(a == 1))
    plt.rcParams['figure.figsize'] = (40.0, 40.0) # set default size of plots
    num_images = len(mislabeled_indices[0])
    for i in range(num_images):
        index = mislabeled_indices[1][i]
        
        plt.subplot(2, num_images, i + 1)
        plt.imshow(X[:,index].reshape(64,64,3), interpolation='nearest')
        plt.axis('off')
        plt.title("Prediction: " + classes[int(p[0,index])].decode("utf-8") + " \n Class: " + classes[y[0,index]].decode("utf-8"))

# %%
print_mislabeled_images(classes, test_x, test_y, predictions_test)

# %% [markdown]
# ***Exercise:*** Identify a few types of images that tends to perform poorly on the model

# %% [markdown]
# Now, lets use the same architecture to predict sentiment of movie reviews. In this section, most of the implementation is already provided. The exercises are mainly to understand what the workflow is when handling the text data.

# %%
import re

# %% [markdown]
# # Dataset

# %% [markdown]
# **Problem Statement**: You are given a dataset ("train_imdb.txt", "test_imdb.txt") containing:
#     - a training set of m_train reviews
#     - a test set of m_test reviews
#     - the labels for the training examples are such that the first 50% belong to class 1 (positive) and the rest 50% of the data belong to class 0(negative)
#
# Let's get more familiar with the dataset. Load the data by completing the function and run the cell below.

# %%
def load_data(train_file, test_file):
    train_dataset = []
    test_dataset = []
    
    # Read the training dataset file line by line
    for line in open(train_file, 'r'):
        train_dataset.append(line.strip())
        
    for line in open(test_file, 'r'):
        test_dataset.append(line.strip())
    return train_dataset, test_dataset

# %%
train_file = "data/train_imdb.txt"
test_file = "data/test_imdb.txt"
train_dataset, test_dataset = load_data(train_file, test_file)

# %%
# This is just how the data is organized. The first 50% data is positive and the rest 50% is negative for both train and test splits.
y = [1 if i < len(train_dataset)*0.5 else 0 for i in range(len(train_dataset))]

# %% [markdown]
# As usual, lets check our dataset

# %%
# Example of a review
index = 10
print(train_dataset[index])
print ("y = " + str(y[index]))
# Out:
# I liked the film. Some of the action scenes were very interesting, tense and well done. I especially liked the opening scene which had a semi truck in it. A very tense action scene that seemed well done.<br /><br />Some of the transitional scenes were filmed in interesting ways such as time lapse photography, unusual colors, or interesting angles. Also the film is funny is several parts. I also liked how the evil guy was portrayed too. I'd give the film an 8 out of 10.
# y = 1

# %%
# Explore your dataset 
m_train = len(train_dataset)
m_test = len(test_dataset)

print ("Number of training examples: " + str(m_train))
print ("Number of testing examples: " + str(m_test))
# Out:
# Number of training examples: 1001
# Number of testing examples: 201

# %% [markdown]
# ## Pre-Processing

# %% [markdown]
# From the example review, you can see that the raw data is really noisy! This is generally the case with the text data. Hence, Preprocessing the raw input and cleaning the text is  essential. Please run the code snippet provided below.
#
# **Exercise**: Explain what pattern the model is trying to capture using re.compile in your report.

# %%
REPLACE_NO_SPACE = re.compile("(\.)|(\;)|(\:)|(\!)|(\')|(\?)|(\,)|(\")|(\()|(\))|(\[)|(\])|(\d+)")
REPLACE_WITH_SPACE = re.compile("(<br\s*/><br\s*/>)|(\-)|(\/)")
NO_SPACE = ""
SPACE = " "

def preprocess_reviews(reviews):
    
    reviews = [REPLACE_NO_SPACE.sub(NO_SPACE, line.lower()) for line in reviews]
    reviews = [REPLACE_WITH_SPACE.sub(SPACE, line) for line in reviews]
    
    return reviews

train_dataset_clean = preprocess_reviews(train_dataset)
test_dataset_clean = preprocess_reviews(test_dataset)

# %%
# Example of a clean review
index = 10
print(train_dataset_clean[index])
print ("y = " + str(y[index]))
# Out:
# i liked the film some of the action scenes were very interesting tense and well done i especially liked the opening scene which had a semi truck in it a very tense action scene that seemed well done some of the transitional scenes were filmed in interesting ways such as time lapse photography unusual colors or interesting angles also the film is funny is several parts i also liked how the evil guy was portrayed too id give the film an  out of
# y = 1

# %% [markdown]
# ## Vectorization

# %% [markdown]
# Now lets create a feature vector for our reviews based on a simple bag of words model. So, given an input text, we need to create a numerical vector which is simply the vector of word counts for each word of the vocabulary. Run the code below to get the feature representation.

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(binary=True, stop_words="english", max_features=2000)
cv.fit(train_dataset_clean)
X = cv.transform(train_dataset_clean)
X_test = cv.transform(test_dataset_clean)

# %% [markdown]
# CountVectorizer provides a sparse feature representation by default which is reasonable because only some words occur in individual example. However, for training neural network models, we generally use a dense representation vector.

# %%
X = np.array(X.todense()).astype(float)
X_test = np.array(X_test.todense()).astype(float)
y = np.array(y)

# %% [markdown]
# ## Model

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(
    X, y, train_size = 0.80
)

# %%
# This is just to correct the shape of the arrays as required by the two_layer_model
X_train = X_train.T
X_val = X_val.T
y_train = y_train.reshape(1,-1)
y_val = y_val.reshape(1,-1)

# %%
### CONSTANTS DEFINING THE MODEL ####
n_x = X_train.shape[0]    
n_h = 200
n_y = 1
layers_dims = (n_x, n_h, n_y)

# %% [markdown]
# We will use the same two layer model that you completed in the previous section for training.

# %%
parameters = two_layer_model(X_train, y_train, layers_dims = (n_x, n_h, n_y), num_iterations = 2500, print_loss=True)
# Out:
# Loss after iteration 0: 0.6930794161691755
# Loss after iteration 100: 0.6930773948080935
# Loss after iteration 200: 0.6930753735285449
# Loss after iteration 300: 0.6930733523698048
# Loss after iteration 400: 0.6930713313213822
# Loss after iteration 500: 0.6930693103792652
# Loss after iteration 600: 0.6930672896059276
# Loss after iteration 700: 0.6930652689612327
# Loss after iteration 800: 0.6930632483267636
# Loss after iteration 900: 0.6930612276906738
# Loss after iteration 1000: 0.6930592071508488
# Loss after iteration 1100: 0.6930571867034228
# Loss after iteration 1200: 0.6930551662763574
# Loss after iteration 1300: 0.6930531458998441
# Loss after iteration 1400: 0.6930511256500166
# Loss after iteration 1500: 0.6930491054723672
# Loss after iteration 1600: 0.6930470854146596
# Loss after iteration 1700: 0.6930450654455831
# Loss after iteration 1800: 0.6930430455733464
# Loss after iteration 1900: 0.6930410258430224
# Loss after iteration 2000: 0.6930390062133823
# Loss after iteration 2100: 0.6930369867033378
# Loss after iteration 2200: 0.6930349673040281
# Loss after iteration 2300: 0.6930329480118862
# Loss after iteration 2400: 0.6930309288096154

# %% [markdown]
# ## Predict the review for our movies!

# %%
predictions_train = predict(X_train, y_train, parameters)
# Out:
# Accuracy: 0.5075000000000001

# %%
predictions_val = predict(X_val, y_val, parameters)
# Out:
# Accuracy: 0.4427860696517413

# %% [markdown]
# ##  Results Analysis
#
# Let's take a look at some examples the 2-layer model labeled incorrectly

# %%
def print_mislabeled_reviews(X, y, p):
    """
    Plots images where predictions and truth were different.
    X -- dataset
    y -- true labels
    p -- predictions
    """
    a = p + y
    mislabeled_indices = np.asarray(np.where(a == 1))
    plt.rcParams['figure.figsize'] = (40.0, 40.0) # set default size of plots
    num_reviews = len(mislabeled_indices[0])
    for i in range(num_reviews):
        index = mislabeled_indices[1][i]
        
        print((" ").join(cv.inverse_transform(X[index])[0]))
        print("Prediction: " + str(int(p[0,index])) + " \n Class: " + str(y[0,index]))

# %%
print_mislabeled_reviews(X_val.T, y_val, predictions_val)
# Out:
# cause change concept did future happened ill interesting left looking movie took want watchable watched written youre
# Prediction: 1
#  Class: 0
# cusack dumb ended funny happy john jokes julia movie predictable really roberts romance shame storyline talented
# Prediction: 1
#  Class: 0
# add beautiful body bored characters cinematography classic complex considered definitely dull exciting fans feel filmed finally gets going having horror huge just lee like looks lots movie mystery parts proper pulled pure scenes sequences shame shots sorts spite theyre thing time youve
# Prediction: 1
#  Class: 0
# able actress box camera certainly characters common completely did didnt different director effective effort emotions english especially expected fact families feel festival film final future genres good great helped hope im intriguing job lead lesser lives local long looked lot movie movies office placed play quite range really recent required river scenery screen season second shots sister star story terms think thought vision wide wont writers year young younger
# Prediction: 0
#  Class: 1
# acting afraid appreciate believe book books bored character charlotte childhood closer completely did edward end eyre favorite finally george great hurt im jane like looks marriage moments moving novel old passion plain play poor pretty rochester scene scott style supposed used version want way william woman york young
# Prediction: 1
#  Class: 0
# best better bored clearly clever completely course dead director effort end evil feature feels figure film forced fun great hard heres hoping isnt just kills lack like little luck main mess minute minutes money picture promise quickly really reasons result savage script sequences short shows story theres tries trying ultimately understand wanted wasnt wish worth
# Prediction: 1
#  Class: 0
# actors actually anymore atmosphere beautiful believe bit boring called care cast character child confused credits decide did different disappointing discovered dont dream dull effect emotional end expected fact film help husband imagery images interesting involving just know known lack like list little looking lot love lover main make man manage matters meant men mother mysterious place plot pointless pretentious random result saw say scenes sense sequences sex shocking situation state sure talking think time wasnt work
# Prediction: 1
#  Class: 0
# acted actors believe brothers clue cold company completely credit does doing dont doubt end episodes fact fast filmed forward game gets given great group hopes involved just laughable led like looking machine making movies old pathetic performance planet point puts quality really scene scott seriously stop trying unfortunately utterly wanted war watching went wish
# Prediction: 1
#  Class: 0
# acting actors actress background bad biggest carry casting characters concept crime didnt dont explained felt girl good harder idea instance like lot movie pretty proper proved realistic really steven story stuff stupid thought time underground weak worse wow wrong years
# Prediction: 1
#  Class: 0
# acting actors ago better blood budget characters comes cool couple cover crap days dialog died doing effects end extreme eyes finally friend girls great guy happen happens head heres house ill im interesting ive just kind like long looking make making maybe movie movies naked oh ok people personality really rented right run running savini scared script seen shots sitting story stuff tell terrible theyre tom track van violence waiting waste way weird whats wrong youve zero
# Prediction: 1
#  Class: 0
# action angles colors especially evil film filmed funny guy id interesting liked opening parts photography portrayed scene scenes time unusual ways
# Prediction: 0
#  Class: 1
# able actually add advice ask awful big consider cover cult did exactly fair feel felt film gave going guys having ideas ill just know leave let literally local love mark matter maybe movie movies nasty need passion place question rate really recommended rent rented said saying sick start strange stuff think thought told turn turned video vote want way
# Prediction: 1
#  Class: 0
# accents action actor audience awful bad band blind cash cast change changes characters cheap check clichés come complete conclusion cop corny dialogue didnt die does dumb dvd effects effort english european faces family fast film final german good got gun guy hard imdb jack john just known knows laughs like lines location looking looks love manages material mess needed nudity old opening piece played playing plot point pointless problems quality right rip scene script second sequel set sign simply stand stolen straight thing thrown time used using usual video villains violence whatsoever wild
# Prediction: 1
#  Class: 0
# ago art ask ass better blood character child cinema classic come confusing cult damn daughter decides doesnt dying ed epic eventually explain failed fate feel film fly followed following game gave half having help host hours house instead issues job just know levels liked literally little long love make male man maybe message minute modern money movie mr need officer oh opening pain people point pointless police possibly probably producer producers purpose read reason relationship save second self shows son star suffers sure thing things thinking tries try turn unknown unrelated want wife wont written years
# Prediction: 1
#  Class: 0
# acting bought characters dont effects enjoy film forget great like look looked minute mistake money place play probably reason saw school screen seen special story stupid things trailer unfortunately warning waste watch went worst wouldnt
# Prediction: 1
#  Class: 0
# addition audience branagh care central character confused core director expect experience film follow happens intelligence issue lead line lost mr obviously patrick piece plot qualities redeeming respect self spend start taste time totally trash unusual values viewer want wonder work writer
# Prediction: 1
#  Class: 0
# ability accent acting annoying aside audience black boring cast character clear comedic cool disturbing doesnt especially events fact fails fan fans fiction film films fit flat flick follows given good great hes horror ideas impression job jones just lack lead level levels like list look looks lost majority make masterpiece meant miss movie murder music obvious obviously performances piece place plot pretty proof quickly role scenes score sequences shes silly small sounds suffers supposed takes talent talking things till title tone trash tries trying victims wasted way werent william win woman won wouldnt young youre
# Prediction: 1
#  Class: 0
# acting ask atmosphere attempt band basic blood boys bring brutal budget build car cause close come common connected contains cradle crap create deal death didnt different disgusting doesnt easily effects endless entire example extremely eyes failure fake fan fear filth girls guts horror idea imagination imagine instead interesting involved ive joke just lead like little look looks lot love make meant mess mind missed movie movies murder obviously offensive opportunity parents parts people performances personally plain pleasure plot potential presence pro production realistic results said say scenes seen self separate series showing shown sick special spent story surely teenagers tension theres think thoughts torture trial try utterly victims violence violent wanting watching way ways worst youre
# Prediction: 1
#  Class: 0
# add aged air award bad beautiful better boring bringing career character classic country death directing director especially film filming films fine finished fly gives god good great impressive instead johnny location look looking looks make obvious pace playing real remarkable robert sad scenery scenes score series shooting shot slow songs spite star starring supposed surprisingly taking taste television tired tried winning woman work worst year
# Prediction: 1
#  Class: 0
# based got involved movie moving mystery oscar review script slow star
# Prediction: 1
#  Class: 0
# actually ahead better box budget burning character charlie come damn development did didnt dont enjoy eye fake far film flick forced genre good guinea guts hand hear heard horror hours interested just know like listen looks lot low making men minutes movie naturally offer painful pretty really recommend say scene scenes second seen set sharp short simply snuff story think thought throwing told torture trying ultimately unless various watching ways went woman worst
# Prediction: 0
#  Class: 1
# cause early effort government heavy past people problems production propaganda short spending sudden time truly using war window
# Prediction: 1
#  Class: 0
# acting actually aside away bad best big charm cheesy close completely cop cut damn disaster doesnt end film funny giant good got hair horror ive just killer laugh look lots love men movie movies music old plays plot ridiculous scene script seen taking terrible terribly trash truly words worked worst written
# Prediction: 1
#  Class: 0
# acting ago audience conversations definitely does dont entire fact fails film good hate heard hour humor im intended ive know lacks life like matter maybe movie nudity offers point possible powerful probably recommend saw script seen single stuff sure thing thoughts video watch worst
# Prediction: 1
#  Class: 0
# achieve actors ago art attempt average bad best brilliant camera care caused characters cinematography commentary compared completely copy course did didnt direction effort energy explain features film films forced hand holding hours inside inspired instead lack lets light like likely little look lot low maybe means meant movie non nowadays numbers parts pass people poor qualities realistic really reason sad sadly saw seeing seen self significant situations state surprise takes taste technical theater treated victor way wonder worst years youll
# Prediction: 1
#  Class: 0
# accept acting action actually added ages attractive bad better biblical bunch calls changes characters code complete computer cute daughter decide definitely despite device dialogue did didnt direction does dream example explanation far figured film finally followed genuine god good hadnt help high honestly horrible includes jesus just lack lame later liked location long low major mentioned michael minutes moments motion movie news omega pacing paid pass pay personal picture place plot points poorly possibly producers proved quality quickly quite ridiculous run sat scene scenes school seat seconds seen sequence sequences shooting shots situations spoilers stars stay terrible thats theres things think time touch tough trying turns unfortunately unnecessary van wanted weird worse worst writing years york young
# Prediction: 1
#  Class: 0
# absolutely acting action actor angie attention away bad boring cast characters clichéd cuba death direction does doesnt dull end enjoyable entertaining fails film game good gooding ill isnt james jr lead make makes movie news plain point predictable president reporter role script secret shows simple story straight sure surrounding talented thought type woods writing
# Prediction: 1
#  Class: 0
# actors agree arent audience bits book character check comment didnt doesnt dont enjoy example eyre feels felt fully george given goes good happening hardly im jane justice know left let love main make marriage mins movie mr need read really rochester roles say school scott sense series sorry story suddenly thing time version watch watching writers years york
# Prediction: 1
#  Class: 0
# act actors avoid bad brain bucks budget called come company completely cons does female filmed films gore gross horrible horror killed lame life like lives looks movie negative people plot rating really reporter review runs save simply stories tells thats theyre
# Prediction: 1
#  Class: 0
# act acts apart bad believe cinematography did directing direction director family given great horrible job just kind like look lot movie opinion performance really running say seeing sleep song stories story think true ugly villains
# Prediction: 1
#  Class: 0
# accent american beautiful british close feels film friend half high horror hour insane know laughed long lost lot movie place probably purpose released scared seen slowly stick supposed takes terrible thing time times want waste
# Prediction: 1
#  Class: 0
# accent acting attempt australian authentic bad case cinematography close come compelling content cool disturbing dont downright drama editing ended engaging excellent fact fan fast fellow film great half happened hear heard hollywood interesting just language line makes managed movies naturally neill nice novel outside pacing performances pick picture plot quite read really recommend released situations standard stands story streep strong stuff thing times truth understand year youll
# Prediction: 0
#  Class: 1
# ability acting actor ages anti better cheap cinema complete confused day decent direction disappointed disappointment does dont dull dvd explanation film finally finding flat gate good got great guess intriguing kind lead like liked love main meet mouth movie performance plot poor premise remind required result rip saw say store story tell thought took tv wanted way week written
# Prediction: 1
#  Class: 0
# absolutely actually anybody appeal army attempt bad believable bit books boys brought character characters child cliché clichés clue comic doubt endless especially explain extreme far film finish flaws forever fully garbage goes got id impossible ive just like list little meant memories mindless moment movie movies nearly obviously old pass past piece plot production qualities reading really redeeming ridiculous russian scene seen short single storyline straight takes technical time total trash truly try using utterly values war waste watching worst worth wow written wwii year
# Prediction: 1
#  Class: 0
# attempts bed capable cast caught character chases choice continue cop david dead death deserves director doing dumb end entire explanation fact factor felt finally gives goes good got happened hundreds isnt ive just killed killer kind knew know later like mad men movie named naturally odd potential prior process ready really right room screen seen shots slasher stop sure suspect thats thing thrown title victims woman women working
# Prediction: 1
#  Class: 0
# acting actor better chemistry completely dance expect fall felt film flat given hours instead let like little nature obviously painful passion performance personal revealing scenes sitting story strange supposedly victim watch wise wouldnt
# Prediction: 1
#  Class: 0
# accept action appear attempt attempts basic budget capable case cast despite directed earth effective effects effort episodes escape essentially events falls fiction films genre grave imagination lacking largely law lie life members mistake moon opera particular players plot present producers production quality result science screen short space special states station suspense team themes unfortunately various violent waste work
# Prediction: 1
#  Class: 0
# acting bad black came characters director doubt ending excellent fan features film good just large laugh little look lot lovely moment music need painful paris particularly quite really redeeming romance script self shes shots singing soon star starts story sure watch white wouldnt writer youre
# Prediction: 1
#  Class: 0
# better body cast central cinema come coming comments company computer decides die entertaining exist failed fall fan film films genius gets getting going great hard hey highly hollywood house idea interested judging latest lesson lessons like make making man member money movie movies near potential premise puts review reviews role scenes seen set shock soon stupid taken takes type unless unrelated wish wow writer writing yes zero
# Prediction: 1
#  Class: 0
# actually agree baby characters country did dingo dog episode goes gonna hes high hunter just kid know knowledge knows lady like lines longer lot mad major movie notice oh place proves purpose real right saying sex shots small snakes steve stuff takes things thought try want watched
# Prediction: 1
#  Class: 0
# bar based bizarre couple dont earth end entertainment example film films finally forward friend half inside laughed like little looking miss paris pictures pretentious really saw scene scenes seeing sorry spent theater time value waiting way wife
# Prediction: 1
#  Class: 0
# arent attempt building care christopher crazy cusack did didnt does door douglas fell funny gets girl happen hour job jones just laugh main movie ones really rest right roberts scenes suicide supposed ugly watch yeah
# Prediction: 1
#  Class: 0
# acting admit answer arts away better bunch camera cinema costumes credits did film flat garbage glad going hard im impressed knowing lady laughable leading lesson lessons life making number plot plus public question recently released rest revealed saw script seen self shouldnt tedious tension terrible thats think took way whats world worst wrong wrote youve
# Prediction: 1
#  Class: 0
# admit almighty attempt big bruce carrey cast cheesy comedy dont end enjoyable fan feel funny gets gone havent help hilarious ill im jim just know let light like movie movies music note poor positive really rest reviews saying seen shows somewhat start steve thinking want writers youre
# Prediction: 0
#  Class: 1
# acting actor bad fan funny great hardly impossible kid movie movies players pro really seen shaq think way works worst zero
# Prediction: 1
#  Class: 0
# acting bored character characters choice connected connection consists cut dead definitely directors doesnt feel feeling general horror hours lack later lies long main mediocre minutes movie murder non order pictures plot presented required revealed saw scenes shown strong taken theyre type version violence way work
# Prediction: 1
#  Class: 0
# age ball big blood camp characters daughter didnt double driving effect film flick free good hell id im job just know like looking looks main movie movies nudity ones place played problem released season seen story sucked sure takes theres thing vision women young
# Prediction: 1
#  Class: 0
# action age body brain building certainly computer crazy damme daughter dead entertaining especially fan fi fights folks genius goes going goldberg good government guess hes humor just keeps king lame later latest like manages mean named new original particularly perfect power pretty pro reason run sci sequel shoot site snake soldiers sort step super takes thriller train usual van war white working wrong year years youre
# Prediction: 1
#  Class: 0
# appeared art audience bar battle bizarre bloody camera clear come concept david death definitely despite didnt different director doesnt entirely expecting extremely fiction film films finish follows gets goes good got happen happened having heard hidden im impossible inner just known lies like little lives looking lost make maybe message money movie movies non number okay open paid particularly past people played point present problem range rating ratings reach rent revolves right rip said sake say science separate share sister spent start starting story street success suddenly surprise tales terrible theme theres thing things think time truly truth universal various wall watched way ways weird wonder work
# Prediction: 1
#  Class: 0
# acting bad black clever comedy ending episode half just maybe paced predictable premise slow tales want worked
# Prediction: 1
#  Class: 0
# act away come comment didnt direct dont genie guess happen just kill know like maybe movie park people plot point really remember sense shaq story stupid terrible theres thinking time watched whatsoever wish worth
# Prediction: 1
#  Class: 0
# accents actors better branagh british character characters charismatic charm doesnt drunk future head heard house just kenneth line movie mysterious note obvious people performances plot probably saying setting used wooden written
# Prediction: 1
#  Class: 0
# acting actually apart attempts attention available avoid away bad believe best better bizarre blair book british buying cheap claims content convincing cover cradle creature decent detective does dvd effects end evidence exactly feel film films filth finished frankly going good gore great guess guy head heard horror house im impressed instead ive key know known laughable like likely look looks love mans mark movie near obviously old opening opportunity outside people piece point quite running runs say scene seen set sets shot shots sign special standard terrible thats things title took tv want way witch worse worst
# Prediction: 1
#  Class: 0
# anybody beginning breaking brilliant carter characters course daniel doing dont dr end episodes fan favorite fi fighting free friend going good hope human ive jack jackson just kids kind leave life looking lost loved makes movie new oneill original pretty qualities record ridiculous sci season smart space started stories stupid technology th think waiting watching women
# Prediction: 0
#  Class: 1
# acting angel angels bad body british concept day dont effects faces famous forest gives gore got heaven help high joan like limited little long look mediocre minute minutes mother movie naked night paris plus presence range really run savini scenes screen sure talk time tom
# Prediction: 1
#  Class: 0
# awful best better boring children comedy does fast flick funniest funny going got great helped husband kind like lines make money movie parts people reality recommend showed slow stuff stupid sucked thanks think thought time waste writer
# Prediction: 1
#  Class: 0
# according acting american attempt awful bad believe better big billy bit bloody boring cast caused century character charles cover crappy deal decide design desperate did director disappointed dont dvd edward emotion emotions end ended ending english episode escape expectations eyes fashion feelings felt figured films finale finally forever forth frank girl good happened hard hearing help hit hoping horrible horror id im images imdb interesting ive japanese john journey just killer kind know lacking leave left like long look looked looking love lucky main make makes man master masters maybe mean memorable middle minutes moves movie music pace pain place played plays point pointless portrayal probably promising purpose quiet really red rest return review ruined sake say scene scenes seeking seen sense series showing shows sitting slow smile sort story style supposed takes tale tell tells terrible th thats theme thing things think thinking thought time times tired title told turns tv used violence violent visuals warning watch watching way whatsoever woman words worth wrote youve
# Prediction: 1
#  Class: 0
# acting adds agree camera care character characters common completely cop cruise decent didnt dying episodes event eyes falling father feeling film girl good great happen happened having held hold hour idea ideas john know like little lot majority maybe memory minute monster particular particularly paul people performance pieces played plays reason recent reminded revealed ridiculous sad said say secret self series shut songs spend stupid sweet theatre theme time tom truly unexpected want wide
# Prediction: 1
#  Class: 0
# alexander annoying away best changing characters christian crying does effect endless events fantastic film filming films final home husband insane ive joan job kill life lighting maybe mom motion party people plays point poor real role scene scenes script seen series setting son soon spend spending spends st starts step themes time tries turns unfortunately whilst
# Prediction: 1
#  Class: 0
# act acting action actors bad best blood crap damme death end far goldberg good great jean michael movie movies ok ones rating reason scenes seen stars sudden watch watching white worst worth
# Prediction: 1
#  Class: 0
# actor allowed aside ask audience away better change children course crap cut daughter director enjoyed especially festival film films hollywood just king learned life line making masks movie new original overlooked questions real really saw self son stories time today told wont
# Prediction: 0
#  Class: 1
# barely basic boring considered cradle dialog did effects fear half hearing high instead line make minutes movie need poorly predictable proof scary school sense sexual shocking shot special storytelling straight sure things unfortunately video visual wants way worth
# Prediction: 1
#  Class: 0
# action american best cool drama english especially good japanese kudos language laugh lord love make movie movies original romance scene story uses watch years
# Prediction: 0
#  Class: 1
# acting away beautifully biggest burt came character drinking fact failure fast fell general help hoping job movie movies night notice played promising real right screen single state thats walk way
# Prediction: 1
#  Class: 0
# awful bad big boring branagh cat date expected fan father figure film forever got half honestly huge interesting ive john jr kenneth lawyer like mixed money moves movie movies night pity powers read rest robert seen sent story talent time tom wanted watching way went wish worst wrong
# Prediction: 1
#  Class: 0
# action believe changes director episode film hard humanity humor likes making mindless movie parts police provoking questions stick storyline style thought touching
# Prediction: 0
#  Class: 1
# absolutely accent actor actors actresses annoying branagh cast crap deserves director dont feel film fine great hard hes im kid like man maybe mean performance previous pull really reviewers second simply sit thing town try trying want watch wish wonderful youd
# Prediction: 1
#  Class: 0
# absolutely actually ahead angie appears bed believe bizarre boat body book bunch car characters crap create dialog different drunk dumb edge editing ending ends example fact falls far film finally given half horrific human impossible instead kate lake lead left like line little looked manner minute minutes movie movies mysterious obviously oh parts pathetic performance perspective picture piece plot poorly powers quality quite redeeming ridiculous run said save say scenes seat seen shocking shows simple sort space spend spent spider spoilers stolen story stupid suddenly time trying unfortunately view viewer watching worse worst writers written yeah
# Prediction: 1
#  Class: 0
# absolutely amusing annoying apparently appearing available billy bored came care cast central characters chemistry comedy completely conclusion cusack did director dog fan fantastic film genius genre good gross having high huge humour ideas instead introduced john jones julia just leads let little lover main majority mediocre mention moments movie obviously old parts plain plays plenty poor possible project pure quite really relationship rest roberts role romance romantic screen simply spoilers story supposed talent time times treated turn type utter wasted whatsoever work
# Prediction: 1
#  Class: 0
# acting better big boring brilliant classic clever deep did early fantastic film gets going gone ill ive just like minutes miss moment movies odd pull said sorry stories strange thinking unusual waiting walk watch william worth writer
# Prediction: 1
#  Class: 0
# able actual appears authentic bad basic beginning believe bigger bloody bodies boring boy budget california calls cameo captures cat chair child claimed cliché clichés completely constantly continue cop david death decent deliver detective diamond difficult director dreadful easily effort ending entire explains feeling film flick friends future games genuine gets ghost going gorgeous got griffith help hero highly horror house idea inspired instead isnt just killer killing know la lacks leads legend life like line lines live lives low machine make mess moment movie murder okay order original overly patrick people performance play played players point poorly power powers premise pretty quickly realized really result return robert roles satan say script serial shes simply soon soul spirit spiritual stand starts streets tell terrible thanks thats thriller time tough tried unexpected uses using victims way weak whilst words world writer
# Prediction: 1
#  Class: 0
# actors believe cast consider days dollars early embarrassing frankly given giving guess hard insight intense involved let little make movie murder pick poorly possible predictable spending unless victim worse written
# Prediction: 1
#  Class: 0
# accent achieve acting advice background bad badly barely best big blame california case cause certain challenge chases cinema cliché climax comes common confused cop cops couldve course crap crappy direction directors does doesnt doing dont double editing effect expect explain fact fails fans far feels film fine fit foot fully gets getting goes going gone good gore grown gun guy half hardly hate head hear help hes holding home hot hour ice im imagine india inside isnt just later lead leave life like line location long love make matters meet meets men mention mind minute mood movie movies music narration new notice offers pain people performance photography plain plus police pretentious pretty produced reason reasons recent remember ring said say scene scenes screenplay second sense shooting short shot simply sit solid songs sort stand starts stay story strange streets stupid terms thanks theatre theres thriller thrown time true trying tv use using violence want wanted watch watching way women wont words year youre
# Prediction: 1
#  Class: 0
# actually ago american begin begins big bring buy century circumstances couple does doesnt effects emotional flicks follows happen highly home house husband impact john life like man masterpiece mysterious old outside plot recommended simple special story strange supposedly things turn unknown went woman world
# Prediction: 0
#  Class: 1
# absolutely add bad best better boat book brought cases classic clear cliché close course critics deserves didnt disappointed exactly excitement family felt field film finally giving grew hard hear hero heroes home ill im instead know latest like line mind missing musical names nature non offensive old particularly past poor professional race real reality reviewer ridiculous right rock sadly said scene scenes score sense shot shots shows smile sound spot starting supposed taking talking theres theyve thrill time took town versions water wonderful years yes
# Prediction: 1
#  Class: 0
# achieve acting approach art artistic background box brief cast cheap cinema close come cons considered consists contemporary country dealing deals deserves director fact fan fit good half hard history hope hot huge job just knows like make manage masterpiece meant media members money movie naked near office ones opinion perfect perfectly provide purpose real roles short single small success talent theatrical thing time touching tried usual waiting women word work
# Prediction: 1
#  Class: 0
# acting action actors animal animals asked avoid bad better big buy casting course crocodile decent directing direction dvd entertaining fans fond friends good half horrible hunter idea instead know level like liked live loved matter memories miss mistake movie non ok performance place plot program remembered respect rest school script seeing series son steve tv want wasnt watched way wish worth wouldnt written
# Prediction: 1
#  Class: 0
# actor actresses bad blood boy budget character characters cons conversation cool cradle creative creepy development died doesnt effects end factor far fear filming filth going good gorgeous great happening hard having including just lack language lead leaves left like little lives long looking love low make makes making movie parts people person places pretty pull random rent right sex soundtrack special storyline style talking things thought trying understand violence watched ways werent whats wondering work yes youre
# Prediction: 1
#  Class: 0
# annoying beautiful easily escape films finds force george god goes good great hand high island isnt jane johnny mention people period player present priest robert singer song thing tries try used woman worst worthy years
# Prediction: 1
#  Class: 0
# action art awful bad belongs boring children city dark dialogue direction director disaster extent features fi forget holes inspired laughable lesser list painful performance plot probably production really redeeming sci shame small smith think truly unconvincing utterly values wasnt watch weve
# Prediction: 1
#  Class: 0
# accident avoid bad best car cool didnt effects fans filth hollywood horror know laugh movie real scene seeing special supposed taste theres
# Prediction: 1
#  Class: 0
# bad best disappointed equally expectations gave good guy guys id jane look making missed missing movie oh old predictable probably romance saw say seen shot somewhat tea thought traditional understand unfortunately unless villains years
# Prediction: 1
#  Class: 0
# academy award blind box buy characters comedy dvd expect film going hit killed know lead maybe mean nice play plot things totally ultimately used watch
# Prediction: 1
#  Class: 0
# actresses admit chose disappointed dvd entertaining fact film glad good guy idea im kept know lacks like long look movie paid rented renting savini saw say script shame sister sound tea thats thought tom wasnt wont
# Prediction: 1
#  Class: 0
# accept ago army away bad begins body bucks budget chase comes couple dolph door energy especially exist explained feel feeling fight fighting films flash flick follow forward goes good happens hell human idea ideas involved isnt just key lacks like long looks low lukas make man master member merely middle movie movies needless new order place plays potential previous satan say scene scenes secret sense sort stars story study sucks supposed sure takes theres thrown time underground wish wont years york youll
# Prediction: 1
#  Class: 0
# absolutely acted art audience bad bar beginning came chinese come coming comments course deep didnt director doing drawn end ending entertaining essentially experience faces fact fantastic far feel festival film final following forget fresh fun gonna government half happy hard hidden hollywood hour hours im immediately incredibly intelligent intriguing judging just land late life likable long looked lot loved make making match meaning mention natural new number pain painful point post probably problem promising reading really reason reviews right russian said saw say sense sharp simply society sounds spent started state talking thank theatre thought time took try utter utterly view want wanted warned way week whats whatsoever words working years yes
# Prediction: 1
#  Class: 0
# acting actors boy called cinema cinematic come conclusion course cuba did didnt direction dvd earth end experience feel films following game gooding hilarious im james jr just know laughable like living look looking make mistake movie performance plot political pull questions really reason rent ridiculous room script seriously shows stars terrible theyve thought thriller woods worth wrong
# Prediction: 1
#  Class: 0
# actors artistic day did director entertainment felt film friends happen honest kept knew like love minutes money plot point reading really speak story supposed tried value waiting want waste watching way
# Prediction: 1
#  Class: 0
# actors ask blood cares character conclusion content crap crew damn day disturbing effort ends episode exception family fan fate gets going gore great gross hopes horror hour imagine lot mindless new performances pointless producers production reason season sense series shock stories story tend thinking utter values violence work worse
# Prediction: 1
#  Class: 0
# action add away bad burt car come control days end fast fine good guys include just looking minutes money movie movies nudity past people real run started store thats thing time twist waste way women write writers written years
# Prediction: 1
#  Class: 0
# attractive bad boring came check comparison cop desperate diamond dont early end era extremely film films flick funny great griffith hard head hilarious horror ive jesus justice lacks late later look makes minute movie parts party plays power recommended role seen sense sister star terrible time unless wasnt waste way weak years youre
# Prediction: 1
#  Class: 0
# attempts character comedic easy eccentric ending entertaining eyes falls flat funny goes going health heard hes house just laughs long matter minute movie original predictable president really say simple simply soon steve subject sucked thing totally wasnt work wouldnt
# Prediction: 1
#  Class: 0
# absolutely acting bits casting cheap close come comments completely couldve did direction edge end film gone humor intense literally little loved mediocre movie number perfect phone points read rest ring scary script second spot story thrill time years
# Prediction: 0
#  Class: 1
# air amusing angie arent audience audiences baby bad based basic best better boat bore bored bring business came camera care cast central certainly character characters chemistry class cliché come comedic comedy comes considered costumes couple course day decides deliver despite dialogue did didnt director directors does dont door dumb end engaging entertaining eventually fact failure fantasy far feature feel fell female film finding general gets goes going good grade happens hope humanity humour husband im interesting isnt jokes just kate lacks laughed laughs lead learn leave left light like line little live look lost love mainly majority make makes man mentioned mess michael mildly million moments movie movies nature near need obvious odd outside performance personality play playing plot poor premise present presented probably produce quickly rare rarely real really remarkable respect resulting review rich robert roles romance romantic say screen script seen sense sets shallow shot similar simply small sorts story success successful sure themes thing time times town trying typical unfortunately unlikely usually value way weak woman work working works world worth worthy years yes
# Prediction: 1
#  Class: 0
# acting actor adult ago appearance appeared attempts bad better bigger came cast character check come create created credits despite doing early end fact favor films gone great guys helped horror humor job just kids king let like making man maybe minutes missed movie movies news old people picture placed plot produced saw small things title watched watching werent worked years young
# Prediction: 1
#  Class: 0
# acting annoying bad cheesy cold completely course dark definitely different disaster doesnt effects eventually explained family film films followed gave gets girl god having human inner just keeps knows lame leads lighting little long main makes man matter meets movie mysterious named okay old ones outside person pick poor possible problem really rest revolves rich right sat script seen sense simple special stars storyline supposed tedious theyre thing things trash trust viewer want worse yes
# Prediction: 1
#  Class: 0
# annoying anybody background basic camera care catch check doesnt dont editing end ends film future goes great job julia just know levels like line lot loud make money movie movies music needed pictures plot potential production really said scenes short sorry sound started story taken things think understand voices way work
# Prediction: 1
#  Class: 0
# absolutely acting actors big bit bother boys budget case cases certainly comedy comment course cradle crime crying day deserves doesnt effects especially exciting expectations fair fan far fear features film flick forget genre girls going happens horror humour im instead intended interesting involved just key kind lack laughs lesson lets lie like likely little look low lower make mean mess minor minutes movie movies names needs normally notch offer oh ones pathetic pay performances places play popular production rarely rate really redeeming rest ridiculous rock roll say school script sex special story sure talent thats theyre thing things totally try use victims watch word wouldnt youll youve zero
# Prediction: 1
#  Class: 0
# acting actors actress attempts awful cast cusack different direction director documentary embarrassing ex eyes green idea jones julia just lacking late let little look movie normally potential professional roberts secret standard stars stick talented theme thing truly unfortunately used usually wasnt way wooden work worst
# Prediction: 1
#  Class: 0
# according actors amazed bar come conclusion conversations decent director does doesnt expect experience feel feeling feelings film funny getting good half hear heard hour like listen lives living losing loss lot majority make makes minutes movie movies music ok people probably shame start starts stop story tell think vote walk wanted watch watching witness world worth
# Prediction: 1
#  Class: 0
# bed book classic clichés director early father female final intriguing involved kate kept lady like london love man married obviously old playing plays point project scene self stage strong takes thing treasure type vehicle view whos wife woman wrong young
# Prediction: 1
#  Class: 0
# battle children clear closer evil good important movie rated rating read seen simple story sub thing truly truth unique universal world wrong
# Prediction: 0
#  Class: 1
# action bad bother cgi clever clichés climax come cool cop design disaster disney doesnt end expectations fast feel film future good great know leaves like list live look mainly movie need obviously parts performance plot predictable premise questions scenes spite start stupid supposed touches utterly whats years
# Prediction: 1
#  Class: 0
# absolute acting bible christian code comes comic day deep did familiar fashion god honest horrible im jesus job know movie movies omega people positive present production recommend relief screen seen short terribly trying unless way worst wrong
# Prediction: 1
#  Class: 0
# actors actually arent bad better characters christopher comes convincing depth didnt does effort enjoyed evil film films frame good id just lacking lee live mediocre mind oh ones overly performances premise proper quite really scary thought time wasnt worth
# Prediction: 1
#  Class: 0
# able actress alexander appearance attempts attractive best better career children death despite director does doesnt effect emotional failure film films final flicks friend goes going grace health help hollywood humor husband im interesting island killed lead like long loses loss major make male mildly mind moving note overall pace place plot poor post production project rich role script sense shes snake social society son soon star story street sudden suffering suffers takes tedious tells think tired totally treatment tries turn use values wanted war went woman worse young
# Prediction: 1
#  Class: 0
# acting bad blue camp circumstances clear critics does enjoy extent friend funny gets grace horrible ill im ive just know let life make man mean minutes mission movie movies piece plot porn quality quite saving seen set single situations tell theyre tone tried twists unbelievable watch way weak weird worse youll
# Prediction: 1
#  Class: 0
# bad cast does film films follows girl hold instead just leave looking love man marriage married mindless miss movie moving mr need old plot really rest run saw scared silly sleep slow turns universal victims wait wow
# Prediction: 1
#  Class: 0
# able acting action adds ahead army arts aside attempts audiences bad badly barely begins body breath brought called career cheap clichés code comedic comedy comes comic completely conversation created credit cut damme daughter decides direct direction does dolph earlier early entertaining essentially events exactly excitement explained explanation fair familiar fear film films followed foot getting given goes going goldberg good guess gun happens having hero holes humans ice instead jean joke kills kind knows later leaves leaving lies life like line lines looks loss majority makes manner massive mean means meant michael mind minor minutes moment mystery new obvious order original parts people pleasure plot point points problem production professional project question quickly real really reason relief reporter required rest revolves ridiculous role science score second seconds seeking seen sense sequel sequences series set short shot shut sight soldier soldiers star state stories story strength strong tell tend terrible theatre time times told turned universal values van video view viewer villain villains want watch welcome white wonder work write writer years
# Prediction: 1
#  Class: 0
# able acting animals anymore australia bad believe bit channel children clearly close come continue crocodile cut disney does expectations experience fall family filled film films going guys happened happy having hear hes hope hoping id im imagine involved just like low make man managed member minute movie people plot predictable quiet real really reason right river room say seeing sequel snakes steve stupid telling theyre thought throw time universe want watched way wife willing wonderful wont worked
# Prediction: 1
#  Class: 0
# acting appeared bad based best biblical bit certainly code good line lines little omega plot precious weak years
# Prediction: 1
#  Class: 0
# aspect big bunch carry cast charismatic christopher cinematic cruise cusack days doesnt editing gonna great hard hit im involved isnt ive john jones julia just know lame let like missed names opportunity painful potential pretty right roberts say script shooting single sit surely thing think unnecessary wonder working wow writing youd youre
# Prediction: 1
#  Class: 0

# %% [markdown]
# **Exercise**: Provide explanation as to why these examples were misclassified below.

# %% [markdown]
# **Type your answer here**

# %%
'''
This could happen becuase most of these feedbacks show a trend in sarcasm. What
the code is not understand is the humans way of language in sarcam when then
mean the opposite of what they say which is why the predicted output is the
complete opposite of expected output. 
'''
# Out:
# '\nThis could happen becuase most of these feedbacks show a trend in sarcasm. What\nthe code is not understand is the humans way of language in sarcam when then\nmean the opposite of what they say which is why the predicted output is the\ncomplete opposite of expected output. \n'
